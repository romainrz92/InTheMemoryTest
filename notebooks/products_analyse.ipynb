# %%
from azure.storage.blob import BlobServiceClient
import pandas as pd
from io import StringIO

# %%
connection_string = ""

# Nom du container
container_name = "76byj86oc9kf"
blob_service_client = BlobServiceClient.from_connection_string(connection_string)

# Récupère le container
container_client = blob_service_client.get_container_client(container_name)

clients_file_name = "products.csv"

# %%
blob_products = container_client.get_blob_client(clients_file_name)
blob_data_products = blob_products.download_blob().readall()
df_products = pd.read_csv(StringIO(blob_data_products.decode('utf-8')), sep=';')

print(df_products.head())
print(df_products.count())
# Out:
#                  id            ean                         brand  \
# 0  3594483823563196  6377501104068  Rodriguez, Lopez and Summers
# 1  2477156078856630    16347216844         Rios, Owens and Rocha
# 2  3567228192434526  9295532048120               Rivera and Sons
# 3  6011725263718260  7572611905294               Hawkins-Leonard
# 4  3589934141863061  6033551312630                    Miller LLC
#
#                                          description
# 0  Specific culture suffer would evening final vi...
# 1  Effect security focus future itself either chu...
# 2  Piece send every kid floor listen language imp...
# 3  Sister religious special large under agent ind...
# 4  Economy then fight star trouble identify offer...
# id             5000
# ean            5000
# brand          4944
# description    5000
# dtype: int64

# %%
df_products.isnull().sum()
# Out:
# id              0
# ean             0
# brand          56
# description     0
# dtype: int64

# %%
df_products[~df_products["brand"].isnull()]
# Out:
#                     id            ean                         brand  \
# 0     3594483823563196  6377501104068  Rodriguez, Lopez and Summers
# 1     2477156078856630    16347216844         Rios, Owens and Rocha
# 2     3567228192434526  9295532048120               Rivera and Sons
# 3     6011725263718260  7572611905294               Hawkins-Leonard
# 4     3589934141863061  6033551312630                    Miller LLC
# ...                ...            ...                           ...
# 4994     4619300978171  6309970084336                     Simon LLC
# 4995    38304097039756  6410273721948              Frederick-Martin
# 4997  3594077955257021  2772059258470                    Patel-Ruiz
# 4998  6514105511305735   640883932427                Hicks and Sons
# 4999  3542505562663507  3840270476559                     Allen PLC
#
#                                             description
# 0     Specific culture suffer would evening final vi...
# ...

# %%
df_products[df_products['brand'].isnull()]
# Out:
#                        id            ean brand  \
# 53       6011938333572936  7215219767382   NaN
# 73    4481850844299063719  3744491935157   NaN
# 188      4719237999833066  2632915492724   NaN
# 491       180090541975838  1847467972834   NaN
# 679          676246860347  7662445596512   NaN
# 765      3575003460763405  1593229082791   NaN
# 824   4383989641131434088  4968714655373   NaN
# 1016      180025958169913  5845671276157   NaN
# 1133     4618352758810361  5921655059333   NaN
# 1280     4015215927488089  4618732260423   NaN
# 1411         501834018779  1461319745805   NaN
# 1737     2674722936067990  1594462833652   NaN
# 1808      374994495449862   707900971644   NaN
# 1977      373385082375464  3216145437046   NaN
# 2063     2279782039518801  6778072859812   NaN
# 2090     4812661830231626  6014299725807   NaN
# 2256         676171098194  9449546513901   NaN
# 2500         501871122013  8126126160052   NaN
# 2585        4019956426429  7695713353593   NaN
# ...

# %%
df_products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           5000 non-null   int64
#  1   ean          5000 non-null   int64
#  2   brand        4944 non-null   object
#  3   description  5000 non-null   object
# dtypes: int64(2), object(2)
# memory usage: 156.4+ KB

# %%
doublonsid = df_products[df_products.duplicated(subset='id', keep=False)]
display(doublonsid)
# Out:
# Empty DataFrame
# Columns: [id, ean, brand, description]
# Index: []

# %%
doublonsean = df_products[df_products.duplicated(subset='ean', keep=False)]
display(doublonsean)
# Out:
# Empty DataFrame
# Columns: [id, ean, brand, description]
# Index: []
