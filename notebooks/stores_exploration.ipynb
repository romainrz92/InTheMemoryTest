# %%
pip install pyspark
# Out:
# ...
#
# ...

# %%
from azure.storage.blob import BlobServiceClient
import pandas as pd
from io import StringIO

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
connection_string = ""
# Nom du container
container_name = "76byj86oc9kf"

# Crée un client BlobServiceClient
blob_service_client = BlobServiceClient.from_connection_string(connection_string)

# Récupère le container
container_client = blob_service_client.get_container_client(container_name)

clients_file_name = "stores.csv"

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 16
#      12     return f"{hour:02d}:{minute:02d}"
#      15 df_stores = df_stores.copy()
# ---> 16 df_stores["opening"] = df_stores["opening"].apply(format_hour)
#      17 df_stores["closing"] = df_stores["closing"].apply(format_hour)
#
# File c:\Users\rruiz\Documents\.venv\lib\site-packages\pandas\core\series.py:4935, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4800 def apply(
#    4801     self,
#    4802     func: AggFuncType,
#    (...)
#    4807     **kwargs,
#    4808 ) -> DataFrame | Series:
#    4809     """
#    4810     Invoke function on values of Series.
#    4811
#    (...)
#    4926     dtype: float64
#    4927     """
#    4928     return SeriesApply(
#    4929         self,
#    4930         func,
#    4931         convert_dtype=convert_dtype,
# ...

# %%
blob_stores = container_client.get_blob_client(clients_file_name)
blob_data_stores = blob_stores.download_blob().readall()
df_stores = pd.read_csv(StringIO(blob_data_stores.decode('utf-8')), sep=';')

print(df_stores.head())
print(df_stores.count())
# Out:
#                     id                latlng  opening  closing  type
# 0     4438835056941647  (33.41012,-91.06177)        8       20     0
# 1     2289192660564207  (41.48199,-81.79819)        8       20     1
# 2         639025595690  (42.93369,-72.27814)        8       20     1
# 3     3561934145164427  (44.73941,-93.12577)        8       20     0
# 4  4168704593076572910  (35.61452,-88.81395)        8       20     1
# id         50
# latlng     50
# opening    50
# closing    50
# type       50
# dtype: int64

# %%
def format_hour(val):
    val = int(val)
    if val < 100:  # valeur < 100 => heure pleine, pas minutes
        hour = val
        minute = 0
    else:
        hour = val // 100
        minute = val % 100
    return f"{hour:02d}:{minute:02d}"



df_stores = df_stores.copy()
df_stores["opening"] = df_stores["opening"].apply(format_hour)
df_stores["closing"] = df_stores["closing"].apply(format_hour)

# %%
df_stores[['latitude', 'longitude']] = df_stores['latlng'].str.strip('()').str.split(',', expand=True).astype(float)
df_stores = df_stores[['id', 'latitude', 'longitude', 'opening', 'closing', 'type']]

# %%
print(df_stores.dtypes)
# Out:
# id          int64
# latlng     object
# opening    object
# closing    object
# type        int64
# dtype: object

# %%
display(df_stores)
# Out:
#                      id                 latlng opening closing  type
# 0      4438835056941647   (33.41012,-91.06177)   08:00   20:00     0
# 1      2289192660564207   (41.48199,-81.79819)   08:00   20:00     1
# 2          639025595690   (42.93369,-72.27814)   08:00   20:00     1
# 3      3561934145164427   (44.73941,-93.12577)   08:00   20:00     0
# 4   4168704593076572910   (35.61452,-88.81395)   08:00   20:00     1
# 5       349788575114871   (40.65538,-74.38987)   08:00   20:00     1
# 6      2227038929805094   (32.52515,-93.75018)   08:00   20:00     1
# 7   4872058026985746936  (33.93113,-117.54866)   08:00   20:00     0
# 8      4788063003775978   (38.58894,-89.99038)   08:00   20:00     0
# 9         4187214098379   (26.68451,-80.66756)   08:00   20:00     1
# 10         676278431058   (28.15112,-82.46148)   08:00   20:00     0
# 11     3585959166176689   (26.68451,-80.66756)   08:00   20:00     0
# 12     2223722682655721  (37.73604,-120.93549)   08:00   20:00     1
# ...

# %%
doublons = df_stores[df_stores.duplicated(subset='id', keep=False)]
display(doublons)
# Out:
# Empty DataFrame
# Columns: [id, latlng, opening, closing, type]
# Index: []
